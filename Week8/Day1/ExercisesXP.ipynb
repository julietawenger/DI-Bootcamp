# %% [markdown]
# # Exercises XP

# %% [markdown]
# ## Exercise 1: Traditional vs. Modern NLP: A Comparative Analysis
#
# 1. Create a table comparing and contrasting the traditional and modern NLP paradigms. Include the following aspects:
#
#     - Feature Engineering (manual vs. automatic)
#     - Word Representations (static vs. contextual)
#     - Model Architectures (shallow vs. deep)
#     - Training Methodology (task-specific vs. pre-training/fine-tuning)
#     - Key Examples of Models (e.g., Naïve Bayes, BERT)
#     - Advantages and Disadvantages of each paradigm.
#
# 2. Discuss how the evolution from traditional to modern NLP has impacted the scalability and efficiency of NLP applications.
#
# ___________________________

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# The shift to modern NLP has dramatically boosted scalability and efficiency by:
#
#   - Enabling reusable pre-trained models across tasks
#
#   - Reducing the need for manual feature engineering
#
#   - Capturing rich context and semantics
#
#   - Handling large-scale data with transformer-based architectures
#
# Result: Faster development, better performance, and more versatile NLP systems.

# %% [markdown]
# ## Exercise 2: LLM Architecture and Application Scenarios
#
# For each of the following LLM architectures (BERT, GPT, T5), describe:
#
#   - The core architectural differences (e.g., bidirectional vs. unidirectional, masked language modeling vs. causal language modeling).
#   - A specific real-world application where that architecture excels.
#   - Explain why that specific architecture is well suited for that particular application.
# _________________________________

# %% [markdown]
# BERT
#
# - Architecture: Bidirectional Transformer. Uses Masked Language Modeling (MLM).
#
# - Best For: Text classification (for example, sentiment analysis).
#
# - Why: Bidirectional context helps understand the full sentence, improving comprehension.
#
# GPT
#
# - Architecture: Unidirectional Transformer. Uses Causal Language Modeling.
#
# - Best For: Text generation (for example, chatbots, story writing).
#
# - Why: Predicts the next word naturally, great for fluent generation.
#
# T5
#
# - Architecture: Encoder–Decoder Transformer. Uses Text-to-Text framework.
#
# - Best For: Multi-task NLP (for example, translation, summarization, Q&A).
#
# - Why: Unified format handles diverse tasks by converting everything to text.

# %% [markdown]
# ## Exercise 3: The Benefits and Ethical Considerations of Pre-training
#
#   - Explain in your own words the five key benefits of pre-trained models discussed in the lesson (improved generalization, reduced need for labeled data, faster fine-tuning, transfer learning, and robustness).
#   - Discuss potential ethical concerns associated with pre-training LLMs on massive datasets, such as bias, misinformation, and misuse.
#   - Propose potential mitigation strategies to address these ethical concerns.
# _____________________________

# %% [markdown]
# Improved Generalization:
#
# Pre-trained models learn from massive, diverse data, making them perform well across many tasks.
#
# Reduced Need for Labeled Data:
#
# They already know a lot, so less labeled data is needed during fine-tuning.
#
# Faster Fine-Tuning:
#
# You only need to tweak the model a bit for new tasks — saves time and compute.
#
# Transfer Learning:
#
# Knowledge from one task/domain transfers to others.
#
# Robustness:
#
# Pre-trained models handle noise, typos, and rare inputs better than models trained from scratch.

# %% [markdown]
# Ethical Concerns
#
# Bias: Models may reflect societal, gender, or racial biases present in the training data. To avoid this, it is beneficial to carefully curate and clean training datasets.
#
# Misinformation: They can generate or amplify false or harmful information learned from the web. Similarly, databases need to be cleaned during training and later it is necessary to test de models and correct them.
#
# Misuse: Can be used to create spam, deepfakes, or automate harmful tasks like phishing. To prevent this issue, a strategy is to implement access controls, monitor model usage, and set clear usage policies to restrict harmful applications.

# %% [markdown]
# ## Exercise 4 : Transformer Architecture Deep Dive
#
# 1. Explain Self-Attention and Multi-Head Attention:
# - Describe in detail how the self-attention mechanism works within a Transformer.
# - Explain the purpose and advantages of multi-head attention compared to single-head attention.
# - Provide a concrete example (different from the lesson) of a sentence and illustrate how multi-head attention might process it, focusing on different relationships between words.
#
# 2. Pre-training Objectives:
# - Compare and contrast Masked Language Modeling (MLM) and Causal Language Modeling (CLM).
# - Describe a scenario where MLM would be more appropriate and a scenario where CLM would be more appropriate.
# - Explain why early BERT models used Next Sentence Prediction (NSP) and why modern models tend to avoid it.
#
# 3. Transformer Model Selection:
# - You are tasked with building the following NLP applications. For each, specify which type of Transformer model (Encoder-only, Decoder-only, or Encoder-Decoder) would be most suitable and justify your choice.
#     1. A system that analyzes customer reviews to determine if they are positive, negative, or neutral.
#     2. A chatbot that can generate creative and engaging responses in a conversation.
#     3. A service that automatically translates technical documents from English to Spanish.
#     4. Explain the advantages of the chosen model type for each particular task.
#
# 4. Positional Encoding:
# - Explain the purpose of positional encoding, and why it is important for the transformer architecture.
# - Give an example of a situation where the lack of positional encoding would cause a problem.
#
# _______________________

# %% [markdown]
# 1.
#
# Self-attention enables the model to weigh the importance of different words in a sentence relative to each other. Instead of processing words sequentially (like RNNs), Transformers process all words in parallel. Multi-head attention, on the other hand, extends self-attention by allowing multiple attention layers (heads) to focus on different aspects of the input simultaneously.
#
# For example:
#
# Sentence: "The chef cooked the meal because he was hungry."
#
# One head may focus on "chef" ↔ "cooked",
#  another on "he" ↔ "chef" and another on "meal" ↔ "cooked".

# %% [markdown]
# 2. MLM and CLM:
#
# In MLM the words the model has to predict are masked within a sentence, whereas in CLM, the model predicts the next word given previous words.
#
# MLM is better for understanding/contextual tasks such as sentiment analysis. On the other hand, CLM is better for generation tasks such as text completion or storytelling.
#
# NSP was designed to help BERT understand sentence relationships. However, research showed it didn’t help much and could introduce noise. Modern models often use sentence order prediction or skip it entirely, relying on better pre-training setups.

# %% [markdown]
# 3.
#
# - A system that analyzes customer reviews to determine if they are positive, negative, or neutral.
#
# Encoder-only. This is a case of sentiment analysis.
#
# - A chatbot that can generate creative and engaging responses in a conversation.
#
# Decoder-only. I need creative text generation.
#
# - A service that automatically translates technical documents from English to Spanish.
#
# Encoder-decoder. It is the best for translation.

# %% [markdown]
# 4.
# Transformers have no recurrence or convolution. That means that they treat inputs as a bag of vectors. Positional encoding injects information about word order so the model understands sequence structure.
#
# In the sentence "She loves him" vs. "Him loves she", the words are the same, but meaning is totally different. Without position info, the model would treat them as identical.

# %% [markdown]
# ## Exercise 5: BERT Variations - Choose Your Detective
#
# 1. For each of the following scenarios, identify which BERT variation (RoBERTa, ALBERT, DistilBERT, ELECTRA, XLM-RoBERTa) would be most suitable and explain why:
#   - Scenario 1: Real-time sentiment analysis on mobile app with limited resources.
#   - Scenario 2: Research on legal documents requiring high accuracy.
#   - Scenario 3: Global customer support in multiple languages.
#   - Scenario 4: efficient pretraining, and token replacement detection.
#   - Scenario 5: efficient NLP in resource-constrained environments.
#
# 2. Create a table comparing the key features and trade-offs of each BERT variation discussed in the lesson. Include aspects like:
#
#   - Training data and methods.
#   - Model size and efficiency.
#   - Specific optimizations and innovations.
#   - Ideal use cases.
# _________________________

# %% [markdown]
# 1.
#   - Scenario 1: Real-time sentiment analysis on mobile app with limited resources.
#
#   Most suitable BERT: DistilBERT. It's the one that performs better on real-time.
#
#   - Scenario 2: Research on legal documents requiring high accuracy.
#
#  Most suitable BERT: RoBERTa. It spends less time on theoretical assumptions and more time gathering evidence to improve accuracy.
#
#   - Scenario 3: Global customer support in multiple languages.
#
#  Most suitable BERT: XLM-RoBERTa. It's the multilingual BERT, best suited for translation.
#
#   - Scenario 4: efficient pretraining, and token replacement detection.
#
#  Most suitable BERT: ELECTRA. It's trained by token replacements.
#
#   - Scenario 5: efficient NLP in resource-constrained environments.
#
#   Most suitable BERT: ALBERT. It's focused on making BERT smaller, faster, and more efficient while maintaining accuracy.

# %% [markdown]
# 2.

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# ## Exercise 6: Softmax Temperature - The Randomness Regulator
#
# 1. Temperature Scenarios: Describe how the output of a language model would differ in the following scenarios:
#
#   - Softmax temperature set to 0.2.
#   - Softmax temperature set to 1.5.
#   - Softmax temperature set to 1.
#
# 2. Application Design:
#
#   - You are designing a system that generates personalized bedtime stories for children. Explain how you would use softmax temperature to control the creativity and coherence of the stories.
#   - You are building a system that automatically generates summaries of financial reports. Explain how you would use softmax temperature to ensure accuracy and reliability.
#
# Temperature and Bias:
#
#   Discuss how adjusting softmax temperature might affect the potential for bias in a language model’s output.
#   Give a practical example.
# __________________

# %% [markdown]
# Softmax temperature is like a dial that controls randomness in decision-making. It affects how a model chooses between different possible outputs. When temperature is low (T<1), the choice landscape sharpens, emphasizing the most likely output. The model becomes more confident and deterministic.
# When temperature is high (T>1), the choice landscape flattens, making all possible outputs more equal in probability. The model becomes more random and creative, exploring less common choices.
# When T = 1, the model follows the standard softmax distribution, maintaining a balance between randomness and certainty.
#
# Therefore, in a case in which Softmax Temperature is set to 0.2, the model will be more confident and deterministic. If the Temperature is set to 1.5, the model will behave more creatively, and if the Temperature is set to 1, then model will be balanced.

# %% [markdown]
# - You are designing a system that generates personalized bedtime stories for children. Explain how you would use softmax temperature to control the creativity and coherence of the stories.
#
# I would choose a Softmax Temperature slightly above 1 so that the story is more creative than not but still keepint the stories reasonably coherent.
#
# - You are building a system that automatically generates summaries of financial reports. Explain how you would use softmax temperature to ensure accuracy and reliability.
#
# In order to get accurate and trustworthy results, I would choose a Softmax Temperature well below 1.
