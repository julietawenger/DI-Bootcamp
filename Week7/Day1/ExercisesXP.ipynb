# %% [markdown]
# # Exercises XP

# %%
data = {
    'Review': [
        'At McDonald\'s the food was ok and the service was bad.',
        'I would not recommend this Japanese restaurant to anyone.',
        'I loved this restaurant when I traveled to Thailand last summer.',
        'The menu of Loving has a wide variety of options.',
        'The staff was friendly and helpful at Google\'s employees restaurant.',
        'The ambiance at Bella Italia is amazing, and the pasta dishes are delicious.',
        'I had a terrible experience at Pizza Hut. The pizza was burnt, and the service was slow.',
        'The sushi at Sushi Express is always fresh and flavorful.',
        'The steakhouse on Main Street has a cozy atmosphere and excellent steaks.',
        'The dessert selection at Sweet Treats is to die for!'
    ]
}

# %% [markdown]
# ## Exercise 1: Exploring Text Preprocessing usage, NER and POS tags
#
# 1. Create a function preprocess_text() wich will receive the data as argument and:
#
#     - convert all the text in lower case and tokenize it
#     - remove punctuation
#     - apply a lemmatizer
#     - return the preprocessed strings
#
#
# important:
#
#    - after creating each function, apply it in the dataset and print the result to check that is working properly
#
#
# 2. Create a new dataset with the cleaned text
#
# hint: keep two datasets: the raw data and the preprocessed data
#
#
# 3. Create a function perform_ner() that will receive the text as argument and perform NER tagging on it. Use spacy en_core_web_sm
#
# hint: the function should return the entities text and label_ (example of _labels: ORG, GPE, DATE)
#
#
# 4. Create a function perform_pos_tagging() that will receive the text as argument and perform POS tagging on it.
#
# hint: use nltk pos_tag method
#
#
# 5. Let’s apply the functions in the dataset, analyze the outputs applying it in the preprocessed data and in the raw data

# %%
conda install -c conda-forge spacy=3.4.4
# Out:
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\julie\Anaconda3
#
#   added / updated specs:
#     - spacy=3.4.4
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _ipyw_jlab_nb_ext_conf-0.1.0|           py38_0         170 KB
#     anaconda-client-1.11.0     |     pyhd8ed1ab_1          72 KB  conda-forge
#     anaconda-navigator-2.1.0   |   py38haa95532_0         5.9 MB
#     anyio-3.6.2                |     pyhd8ed1ab_0          83 KB  conda-forge
#     argon2-cffi-21.3.0         |     pyhd8ed1ab_0          15 KB  conda-forge
#     argon2-cffi-bindings-21.2.0|   py38h294d835_2          35 KB  conda-forge
#     arrow-0.10.0               |             py_1          30 KB  conda-forge
#     astroid-2.11.6             |   py38haa244fe_0         353 KB  conda-forge
#     asttokens-2.1.0            |     pyhd8ed1ab_0          26 KB  conda-forge
#     backports-1.0              |     pyhd3eb1b0_2         185 KB
#     backports.functools_lru_cache-1.6.4|     pyhd3eb1b0_0           9 KB
#     backports.weakref-1.0.post1|             py_1           7 KB
#     bcrypt-3.2.2               |   py38h294d835_0          41 KB  conda-forge
#     binaryornot-0.4.4          |     pyhd3eb1b0_1         375 KB
#     brotlipy-0.7.0             |py38h294d835_1004         329 KB  conda-forge
#     ca-certificates-2022.9.24  |       h5b45459_0         189 KB  conda-forge
#     catalogue-2.0.8            |   py38haa244fe_1          33 KB  conda-forge
#     certifi-2022.9.24          |     pyhd8ed1ab_0         155 KB  conda-forge
#     cffi-1.15.1                |   py38hd8c33c5_0         223 KB  conda-forge
#     chardet-5.0.0              |   py38haa244fe_1         250 KB  conda-forge
#     clyent-1.2.2               |             py_1           9 KB  conda-forge
#     conda-4.12.0               |   py38haa244fe_0         1.0 MB  conda-forge
#     conda-build-3.21.7         |   py38haa95532_0         586 KB
#     conda-pack-0.6.0           |     pyhd3eb1b0_0          28 KB
#     conda-package-handling-1.8.1|   py38h31c79cd_1         751 KB  conda-forge
#     conda-verify-3.4.2         |             py_1          25 KB
#     cookiecutter-1.7.2         |     pyhd3eb1b0_0          89 KB
#     cryptography-37.0.4        |   py38hb7941b4_0         1.1 MB  conda-forge
#     cycler-0.11.0              |     pyhd8ed1ab_0          10 KB  conda-forge
#     cymem-2.0.6                |   py38h885f38d_3          34 KB  conda-forge
#     cython-blis-0.7.8          |   py38hbdcd294_0         5.6 MB  conda-forge
#     debugpy-1.6.3              |   py38h885f38d_0         3.2 MB  conda-forge
#     dill-0.3.6                 |     pyhd8ed1ab_1          81 KB  conda-forge
#     docutils-0.17.1            |   py38haa244fe_3         769 KB  conda-forge
#     entrypoints-0.4            |     pyhd8ed1ab_0           9 KB  conda-forge
#     et_xmlfile-1.0.1           |          py_1001          11 KB  conda-forge
#     executing-1.2.0            |     pyhd8ed1ab_0          24 KB  conda-forge
#     flit-core-3.8.0            |     pyhd8ed1ab_0          45 KB  conda-forge
#     future-0.18.2              |     pyhd8ed1ab_6         356 KB  conda-forge
#     h5py-3.7.0                 |   py38h3de5c98_0         1.0 MB
#     importlib-metadata-4.8.1   |   py38haa244fe_1          33 KB  conda-forge
#     inflection-0.5.1           |     pyh9f0ad1d_0           9 KB  conda-forge
#     ipykernel-6.17.1           |     pyh025b116_0         100 KB  conda-forge
#     ipython-8.6.0              |     pyh08f2357_1         559 KB  conda-forge
#     jaraco.classes-3.2.3       |     pyhd8ed1ab_0          10 KB  conda-forge
#     jedi-0.17.1                |   py38h32f6830_0         943 KB  conda-forge
#     jinja2-time-0.2.0          |     pyhd3eb1b0_2          14 KB
#     jupyter_client-6.1.12      |     pyhd3eb1b0_0          87 KB
#     jupyter_core-5.0.0         |   py38haa244fe_0         110 KB  conda-forge
#     jupyter_server-1.15.6      |     pyhd8ed1ab_0         233 KB  conda-forge
#     keyring-23.9.3             |   py38haa244fe_1          72 KB  conda-forge
#     kiwisolver-1.4.4           |   py38hbd9d945_0          61 KB  conda-forge
#     langcodes-3.3.0            |     pyhd8ed1ab_0         156 KB  conda-forge
#     lazy-object-proxy-1.7.1    |   py38h294d835_1          33 KB  conda-forge
#     lcms2-2.12                 |       h2a16943_0         882 KB  conda-forge
#     libblas-3.9.0              |     16_win64_mkl         5.6 MB  conda-forge
#     libcblas-3.9.0             |     16_win64_mkl         5.6 MB  conda-forge
#     liblapack-3.9.0            |     16_win64_mkl         5.6 MB  conda-forge
#     libsodium-1.0.18           |       h8d14728_1         697 KB  conda-forge
#     markupsafe-1.1.1           |   py38h294d835_4          30 KB  conda-forge
#     matplotlib-3.5.3           |   py38haa244fe_2           7 KB  conda-forge
#     matplotlib-base-3.5.3      |   py38he529843_0         7.3 MB  conda-forge
#     mccabe-0.6.1               |             py_1           8 KB  conda-forge
#     menuinst-1.4.19            |   py38haa244fe_1          97 KB  conda-forge
#     mistune-0.8.4              |py38h294d835_1005          55 KB  conda-forge
#     more-itertools-9.0.0       |     pyhd8ed1ab_0          46 KB  conda-forge
#     murmurhash-1.0.8           |   py38h885f38d_0          25 KB  conda-forge
#     mypy_extensions-0.4.3      |   py38haa244fe_6          11 KB  conda-forge
#     navigator-updater-0.5.1    |   py38haa95532_0         3.0 MB
#     nbconvert-6.4.4            |   py38haa244fe_0         588 KB  conda-forge
#     notebook-6.4.12            |     pyha770c72_0         6.3 MB  conda-forge
#     numpy-1.23.2               |   py38h223ccf5_0         6.3 MB  conda-forge
#     openjpeg-2.4.0             |       hb211442_1         238 KB  conda-forge
#     openpyxl-3.0.9             |     pyhd8ed1ab_0         153 KB  conda-forge
#     openssl-1.1.1q             |       h8ffe710_0         5.8 MB  conda-forge
#     pandoc-2.19.2              |       h57928b3_1        18.8 MB  conda-forge
#     pandocfilters-1.5.0        |     pyhd8ed1ab_0          11 KB  conda-forge
#     pathy-0.8.1                |     pyhd8ed1ab_0          39 KB  conda-forge
#     pillow-8.2.0               |   py38h9273828_1         775 KB  conda-forge
#     pip-22.3.1                 |     pyhd8ed1ab_0         1.5 MB  conda-forge
#     pkginfo-1.8.3              |     pyhd8ed1ab_0          23 KB  conda-forge
#     platformdirs-2.5.2         |     pyhd8ed1ab_1          16 KB  conda-forge
#     pluggy-1.0.0               |     pyhd8ed1ab_5          16 KB  conda-forge
#     poyo-0.5.0                 |     pyhd3eb1b0_0          17 KB
#     preshed-3.0.7              |   py38h885f38d_0          84 KB  conda-forge
#     psutil-5.9.1               |   py38h294d835_0         363 KB  conda-forge
#     pure_eval-0.2.2            |     pyhd8ed1ab_0          14 KB  conda-forge
#     pycosat-0.6.3              |py38h294d835_1010          98 KB  conda-forge
#     pydantic-1.9.2             |   py38h294d835_0         1.7 MB  conda-forge
#     pyjwt-2.6.0                |     pyhd8ed1ab_0          21 KB  conda-forge
#     pylint-2.14.4              |     pyhd8ed1ab_0         316 KB  conda-forge
#     pynacl-1.5.0               |   py38h31c79cd_1         1.5 MB  conda-forge
#     pyqt-5.9.2                 |   py38hd77b12b_6         4.2 MB
#     pyrsistent-0.18.1          |   py38h294d835_1          85 KB  conda-forge
#     pysocks-1.7.1              |     pyh0701188_6          19 KB  conda-forge
#     python-3.8.12              |h7840368_2_cpython        19.2 MB  conda-forge
#     python-language-server-0.35.1|             py_0          47 KB
#     python-lsp-jsonrpc-1.0.0   |     pyhd3eb1b0_0          10 KB
#     python-slugify-5.0.2       |     pyhd3eb1b0_0          13 KB
#     python_abi-3.8             |           2_cp38           4 KB  conda-forge
#     pywin32-303                |   py38h294d835_0         6.9 MB  conda-forge
#     pywin32-ctypes-0.2.0       |py38haa244fe_1006          39 KB  conda-forge
#     pywinpty-0.5.7             |   py38haa244fe_1          51 KB  conda-forge
#     pyyaml-6.0                 |   py38h294d835_4         154 KB  conda-forge
#     pyzmq-23.2.1               |   py38h09162b1_0         442 KB  conda-forge
#     qdarkstyle-3.0.2           |     pyhd3eb1b0_0         313 KB
#     qstylizer-0.1.10           |     pyhd3eb1b0_0          17 KB
#     regex-2022.8.17            |   py38h294d835_0         334 KB  conda-forge
#     rtree-1.0.1                |   py38h8b54edf_1          50 KB  conda-forge
#     ruamel_yaml-0.15.80        |py38h294d835_1007         279 KB  conda-forge
#     scipy-1.8.1                |   py38h4990095_2        27.2 MB  conda-forge
#     setuptools-65.5.1          |     pyhd8ed1ab_0         731 KB  conda-forge
#     shellingham-1.5.0          |     pyhd8ed1ab_0          12 KB  conda-forge
# Note: you may need to restart the kernel to use updated packages.
#     sip-4.19.13                |   py38hd77b12b_0         281 KB
#     smart_open-5.2.1           |     pyhd8ed1ab_0          43 KB  conda-forge
#     sniffio-1.3.0              |     pyhd8ed1ab_0          14 KB  conda-forge
#     spacy-3.4.4                |   py38hef0f399_0         9.4 MB
#     spacy-legacy-3.0.10        |     pyhd8ed1ab_0          20 KB  conda-forge
#     spacy-loggers-1.0.3        |     pyhd8ed1ab_0          13 KB  conda-forge
#     sphinx-4.2.0               |     pyhd3eb1b0_1         1.5 MB
#     spyder-4.1.5               |   py38h32f6830_0         8.2 MB  conda-forge
#     spyder-kernels-1.9.4       |   py38h32f6830_0          90 KB  conda-forge
#     srsly-2.4.4                |   py38h885f38d_0         518 KB  conda-forge
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.12.0
#   latest version: 25.3.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#     stack_data-0.6.1           |     pyhd8ed1ab_0          24 KB  conda-forge
#     terminado-0.9.5            |   py38haa244fe_0          26 KB  conda-forge
#     text-unidecode-1.3         |     pyhd3eb1b0_0          69 KB
#     thinc-8.1.0                |   py38h9e3ed74_0         1.1 MB  conda-forge
#     tinycss-0.4                |  pyhd3eb1b0_1002          39 KB
#     tomli-2.0.1                |     pyhd8ed1ab_0          16 KB  conda-forge
#     tomlkit-0.11.6             |     pyha770c72_0          33 KB  conda-forge
#     tornado-6.2                |   py38h294d835_0         655 KB  conda-forge
#     typed-ast-1.5.4            |   py38h294d835_0         136 KB  conda-forge
#     typer-0.4.2                |     pyhd8ed1ab_0          45 KB  conda-forge
#     typing-3.10.0.0            |     pyhd8ed1ab_0           7 KB  conda-forge
#     typing-extensions-3.10.0.2 |       hd3eb1b0_0          12 KB
#     ujson-5.4.0                |   py38h885f38d_0          44 KB  conda-forge
#     unidecode-1.2.0            |     pyhd3eb1b0_0         155 KB
#     wasabi-0.10.1              |     pyhd8ed1ab_1          25 KB  conda-forge
#     watchdog-2.1.9             |   py38haa244fe_1         116 KB  conda-forge
#     webencodings-0.5.1         |             py_1          12 KB  conda-forge
#     websocket-client-1.4.2     |     pyhd8ed1ab_0          43 KB  conda-forge
#     whichcraft-0.6.1           |     pyhd3eb1b0_0          11 KB
#     widgetsnbextension-3.5.2   |   py38haa244fe_1         1.3 MB  conda-forge
#     win_inet_pton-1.1.0        |     pyhd8ed1ab_6           8 KB  conda-forge
#     wrapt-1.14.1               |   py38h294d835_0          49 KB  conda-forge
#     zeromq-4.3.4               |       h0e60522_1         8.9 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       192.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   argon2-cffi        conda-forge/noarch::argon2-cffi-21.3.0-pyhd8ed1ab_0
#   argon2-cffi-bindi~ conda-forge/win-64::argon2-cffi-bindings-21.2.0-py38h294d835_2
#   asttokens          conda-forge/noarch::asttokens-2.1.0-pyhd8ed1ab_0
#   catalogue          conda-forge/win-64::catalogue-2.0.8-py38haa244fe_1
#   cymem              conda-forge/win-64::cymem-2.0.6-py38h885f38d_3
#   cython-blis        conda-forge/win-64::cython-blis-0.7.8-py38hbdcd294_0
#   debugpy            conda-forge/win-64::debugpy-1.6.3-py38h885f38d_0
#   dill               conda-forge/noarch::dill-0.3.6-pyhd8ed1ab_1
#   executing          conda-forge/noarch::executing-1.2.0-pyhd8ed1ab_0
#   flit-core          conda-forge/noarch::flit-core-3.8.0-pyhd8ed1ab_0
#   jaraco.classes     conda-forge/noarch::jaraco.classes-3.2.3-pyhd8ed1ab_0
#   langcodes          conda-forge/noarch::langcodes-3.3.0-pyhd8ed1ab_0
#   lcms2              conda-forge/win-64::lcms2-2.12-h2a16943_0
#   libblas            conda-forge/win-64::libblas-3.9.0-16_win64_mkl
#   libcblas           conda-forge/win-64::libcblas-3.9.0-16_win64_mkl
#   liblapack          conda-forge/win-64::liblapack-3.9.0-16_win64_mkl
#   libsodium          conda-forge/win-64::libsodium-1.0.18-h8d14728_1
#   more-itertools     conda-forge/noarch::more-itertools-9.0.0-pyhd8ed1ab_0
#   murmurhash         conda-forge/win-64::murmurhash-1.0.8-py38h885f38d_0
#   openjpeg           conda-forge/win-64::openjpeg-2.4.0-hb211442_1
#   pandoc             conda-forge/win-64::pandoc-2.19.2-h57928b3_1
#   pathy              conda-forge/noarch::pathy-0.8.1-pyhd8ed1ab_0
#   platformdirs       conda-forge/noarch::platformdirs-2.5.2-pyhd8ed1ab_1
#   preshed            conda-forge/win-64::preshed-3.0.7-py38h885f38d_0
#   pure_eval          conda-forge/noarch::pure_eval-0.2.2-pyhd8ed1ab_0
#   pydantic           conda-forge/win-64::pydantic-1.9.2-py38h294d835_0
#   python_abi         conda-forge/win-64::python_abi-3.8-2_cp38
#   pywin32-ctypes     conda-forge/win-64::pywin32-ctypes-0.2.0-py38haa244fe_1006
#   shellingham        conda-forge/noarch::shellingham-1.5.0-pyhd8ed1ab_0
#   smart_open         conda-forge/noarch::smart_open-5.2.1-pyhd8ed1ab_0
#   spacy              pkgs/main/win-64::spacy-3.4.4-py38hef0f399_0
#   spacy-legacy       conda-forge/noarch::spacy-legacy-3.0.10-pyhd8ed1ab_0
#   spacy-loggers      conda-forge/noarch::spacy-loggers-1.0.3-pyhd8ed1ab_0
#   srsly              conda-forge/win-64::srsly-2.4.4-py38h885f38d_0
#   stack_data         conda-forge/noarch::stack_data-0.6.1-pyhd8ed1ab_0
#   thinc              conda-forge/win-64::thinc-8.1.0-py38h9e3ed74_0
#   tomli              conda-forge/noarch::tomli-2.0.1-pyhd8ed1ab_0
#   tomlkit            conda-forge/noarch::tomlkit-0.11.6-pyha770c72_0
#   typer              conda-forge/noarch::typer-0.4.2-pyhd8ed1ab_0
#   typing             conda-forge/noarch::typing-3.10.0.0-pyhd8ed1ab_0
#   wasabi             conda-forge/noarch::wasabi-0.10.1-pyhd8ed1ab_1
#   websocket-client   conda-forge/noarch::websocket-client-1.4.2-pyhd8ed1ab_0
#   zeromq             conda-forge/win-64::zeromq-4.3.4-h0e60522_1
#
# The following packages will be REMOVED:
#
#   argh-0.26.2-py37_0
#   mkl-service-2.4.0-py37h2bbff1b_0
#   mkl_fft-1.3.1-py37h277e83a_0
#   mkl_random-1.2.2-py37hf11a4ad_0
#   numpy-base-1.21.2-py37h0829f74_0
#   pyreadline-2.1-py37_1
#   wincertstore-0.2-py37haa95532_2
#
# The following packages will be UPDATED:
#
#   anaconda-client    pkgs/main/win-64::anaconda-client-1.9~ --> conda-forge/noarch::anaconda-client-1.11.0-pyhd8ed1ab_1
#   anyio              pkgs/main/win-64::anyio-2.2.0-py37haa~ --> conda-forge/noarch::anyio-3.6.2-pyhd8ed1ab_0
#   astroid            pkgs/main::astroid-2.6.6-py37haa95532~ --> conda-forge::astroid-2.11.6-py38haa244fe_0
#   bcrypt             pkgs/main::bcrypt-3.2.0-py37he774522_0 --> conda-forge::bcrypt-3.2.2-py38h294d835_0
#   brotlipy           pkgs/main::brotlipy-0.7.0-py37h2bbff1~ --> conda-forge::brotlipy-0.7.0-py38h294d835_1004
#   cffi                pkgs/main::cffi-1.14.6-py37h2bbff1b_0 --> conda-forge::cffi-1.15.1-py38hd8c33c5_0
#   chardet            pkgs/main::chardet-4.0.0-py37haa95532~ --> conda-forge::chardet-5.0.0-py38haa244fe_1
#   conda-build                                 3.17.7-py37_0 --> 3.21.7-py38haa95532_0
#   conda-package-han~ pkgs/main::conda-package-handling-1.7~ --> conda-forge::conda-package-handling-1.8.1-py38h31c79cd_1
#   cryptography       pkgs/main::cryptography-3.4.8-py37h71~ --> conda-forge::cryptography-37.0.4-py38hb7941b4_0
#   cycler             pkgs/main/win-64::cycler-0.10.0-py37_0 --> conda-forge/noarch::cycler-0.11.0-pyhd8ed1ab_0
#   docutils           pkgs/main::docutils-0.17.1-py37haa955~ --> conda-forge::docutils-0.17.1-py38haa244fe_3
#   entrypoints        pkgs/main/win-64::entrypoints-0.3-py3~ --> conda-forge/noarch::entrypoints-0.4-pyhd8ed1ab_0
#   future             pkgs/main/win-64::future-0.18.2-py37_1 --> conda-forge/noarch::future-0.18.2-pyhd8ed1ab_6
#   h5py                                 3.2.1-py37h3de5c98_0 --> 3.7.0-py38h3de5c98_0
#   importlib-metadata pkgs/main::importlib-metadata-4.8.1-p~ --> conda-forge::importlib-metadata-4.8.1-py38haa244fe_1
#   ipykernel          pkgs/main/win-64::ipykernel-5.3.4-py3~ --> conda-forge/noarch::ipykernel-6.17.1-pyh025b116_0
#   ipython            pkgs/main/win-64::ipython-7.29.0-py37~ --> conda-forge/noarch::ipython-8.6.0-pyh08f2357_1
#   jupyter_core       pkgs/main::jupyter_core-4.8.1-py37haa~ --> conda-forge::jupyter_core-5.0.0-py38haa244fe_0
#   jupyter_server     pkgs/main/win-64::jupyter_server-1.4.~ --> conda-forge/noarch::jupyter_server-1.15.6-pyhd8ed1ab_0
#   keyring                  pkgs/main::keyring-18.0.0-py37_0 --> conda-forge::keyring-23.9.3-py38haa244fe_1
#   kiwisolver         pkgs/main::kiwisolver-1.3.1-py37hd77b~ --> conda-forge::kiwisolver-1.4.4-py38hbd9d945_0
#   lazy-object-proxy  pkgs/main::lazy-object-proxy-1.6.0-py~ --> conda-forge::lazy-object-proxy-1.7.1-py38h294d835_1
#   markupsafe         pkgs/main::markupsafe-1.1.1-py37hfa6e~ --> conda-forge::markupsafe-1.1.1-py38h294d835_4
#   matplotlib         pkgs/main::matplotlib-3.4.3-py37haa95~ --> conda-forge::matplotlib-3.5.3-py38haa244fe_2
#   matplotlib-base    anaconda::matplotlib-base-3.4.3-py37h~ --> conda-forge::matplotlib-base-3.5.3-py38he529843_0
#   menuinst           pkgs/main::menuinst-1.4.18-py37h59b6b~ --> conda-forge::menuinst-1.4.19-py38haa244fe_1
#   mistune            pkgs/main::mistune-0.8.4-py37hfa6e2cd~ --> conda-forge::mistune-0.8.4-py38h294d835_1005
#   mypy_extensions    pkgs/main::mypy_extensions-0.4.3-py37~ --> conda-forge::mypy_extensions-0.4.3-py38haa244fe_6
#   navigator-updater                            0.2.1-py37_0 --> 0.5.1-py38haa95532_0
#   nbconvert          pkgs/main::nbconvert-6.1.0-py37haa955~ --> conda-forge::nbconvert-6.4.4-py38haa244fe_0
#   notebook           pkgs/main/win-64::notebook-6.0.3-py37~ --> conda-forge/noarch::notebook-6.4.12-pyha770c72_0
#   numpy              pkgs/main::numpy-1.21.2-py37hfca59bb_0 --> conda-forge::numpy-1.23.2-py38h223ccf5_0
#   pandocfilters      pkgs/main/win-64::pandocfilters-1.4.3~ --> conda-forge/noarch::pandocfilters-1.5.0-pyhd8ed1ab_0
#   pip                pkgs/main/win-64::pip-21.2.4-py37haa9~ --> conda-forge/noarch::pip-22.3.1-pyhd8ed1ab_0
#   pkginfo            pkgs/main/win-64::pkginfo-1.7.1-py37h~ --> conda-forge/noarch::pkginfo-1.8.3-pyhd8ed1ab_0
#   pluggy             pkgs/main/win-64::pluggy-1.0.0-py37ha~ --> conda-forge/noarch::pluggy-1.0.0-pyhd8ed1ab_5
#   psutil             pkgs/main::psutil-5.8.0-py37h2bbff1b_1 --> conda-forge::psutil-5.9.1-py38h294d835_0
#   pycosat            pkgs/main::pycosat-0.6.3-py37h2bbff1b~ --> conda-forge::pycosat-0.6.3-py38h294d835_1010
#   pyjwt              pkgs/main/win-64::pyjwt-2.1.0-py37haa~ --> conda-forge/noarch::pyjwt-2.6.0-pyhd8ed1ab_0
#   pylint             pkgs/main/win-64::pylint-2.9.6-py37ha~ --> conda-forge/noarch::pylint-2.14.4-pyhd8ed1ab_0
#   pynacl             pkgs/main::pynacl-1.4.0-py37h62dcd97_1 --> conda-forge::pynacl-1.5.0-py38h31c79cd_1
#   pyqt                                 5.9.2-py37h6538335_2 --> 5.9.2-py38hd77b12b_6
#   pyrsistent         pkgs/main::pyrsistent-0.18.0-py37h196~ --> conda-forge::pyrsistent-0.18.1-py38h294d835_1
#   pysocks            pkgs/main/win-64::pysocks-1.7.1-py37_1 --> conda-forge/noarch::pysocks-1.7.1-pyh0701188_6
#   python                pkgs/main::python-3.7.11-h6244533_0 --> conda-forge::python-3.8.12-h7840368_2_cpython
#   pywin32             pkgs/main::pywin32-228-py37hbaba5e8_1 --> conda-forge::pywin32-303-py38h294d835_0
#   pywinpty                 pkgs/main::pywinpty-0.5.7-py37_0 --> conda-forge::pywinpty-0.5.7-py38haa244fe_1
#   pyyaml               pkgs/main::pyyaml-6.0-py37h2bbff1b_1 --> conda-forge::pyyaml-6.0-py38h294d835_4
#   pyzmq              pkgs/main::pyzmq-22.2.1-py37hd77b12b_1 --> conda-forge::pyzmq-23.2.1-py38h09162b1_0
#   regex              pkgs/main::regex-2021.8.3-py37h2bbff1~ --> conda-forge::regex-2022.8.17-py38h294d835_0
#   rtree               pkgs/main::rtree-0.9.7-py37h2eaa2aa_1 --> conda-forge::rtree-1.0.1-py38h8b54edf_1
#   scipy               pkgs/main::scipy-1.7.1-py37hbe87c03_2 --> conda-forge::scipy-1.8.1-py38h4990095_2
#   setuptools         pkgs/main/win-64::setuptools-58.0.4-p~ --> conda-forge/noarch::setuptools-65.5.1-pyhd8ed1ab_0
#   sip                                 4.19.8-py37h6538335_0 --> 4.19.13-py38hd77b12b_0
#   sniffio            pkgs/main/win-64::sniffio-1.2.0-py37h~ --> conda-forge/noarch::sniffio-1.3.0-pyhd8ed1ab_0
#   terminado          pkgs/main::terminado-0.9.4-py37haa955~ --> conda-forge::terminado-0.9.5-py38haa244fe_0
#   tornado             pkgs/main::tornado-6.1-py37h2bbff1b_0 --> conda-forge::tornado-6.2-py38h294d835_0
#   typed-ast          pkgs/main::typed-ast-1.4.3-py37h2bbff~ --> conda-forge::typed-ast-1.5.4-py38h294d835_0
#   ujson               pkgs/main::ujson-4.0.2-py37hd77b12b_0 --> conda-forge::ujson-5.4.0-py38h885f38d_0
#   watchdog           pkgs/main::watchdog-2.1.3-py37haa9553~ --> conda-forge::watchdog-2.1.9-py38haa244fe_1
#   widgetsnbextension pkgs/main::widgetsnbextension-3.5.1-p~ --> conda-forge::widgetsnbextension-3.5.2-py38haa244fe_1
#   win_inet_pton      pkgs/main/win-64::win_inet_pton-1.1.0~ --> conda-forge/noarch::win_inet_pton-1.1.0-pyhd8ed1ab_6
#   wrapt              pkgs/main::wrapt-1.12.1-py37he774522_1 --> conda-forge::wrapt-1.14.1-py38h294d835_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   arrow               pkgs/main/win-64::arrow-0.13.1-py37_0 --> conda-forge/noarch::arrow-0.10.0-py_1
#   ca-certificates    pkgs/main::ca-certificates-2024.12.31~ --> conda-forge::ca-certificates-2022.9.24-h5b45459_0
#   certifi            pkgs/main/win-64::certifi-2022.12.7-p~ --> conda-forge/noarch::certifi-2022.9.24-pyhd8ed1ab_0
#   clyent              pkgs/main/win-64::clyent-1.2.2-py37_1 --> conda-forge/noarch::clyent-1.2.2-py_1
#   conda              pkgs/main::conda-4.12.0-py37haa95532_0 --> conda-forge::conda-4.12.0-py38haa244fe_0
#   et_xmlfile         anaconda/win-64::et_xmlfile-1.1.0-py3~ --> conda-forge/noarch::et_xmlfile-1.0.1-py_1001
#   inflection         pkgs/main/win-64::inflection-0.5.1-py~ --> conda-forge/noarch::inflection-0.5.1-pyh9f0ad1d_0
#   jedi                        pkgs/main::jedi-0.17.1-py37_0 --> conda-forge::jedi-0.17.1-py38h32f6830_0
#   mccabe              pkgs/main/win-64::mccabe-0.6.1-py37_1 --> conda-forge/noarch::mccabe-0.6.1-py_1
#   openpyxl           anaconda/win-64::openpyxl-3.0.10-py37~ --> conda-forge/noarch::openpyxl-3.0.9-pyhd8ed1ab_0
#   openssl              pkgs/main::openssl-1.1.1w-h2bbff1b_0 --> conda-forge::openssl-1.1.1q-h8ffe710_0
#   pillow             pkgs/main::pillow-8.4.0-py37hd45dc43_0 --> conda-forge::pillow-8.2.0-py38h9273828_1
#   ruamel_yaml        pkgs/main::ruamel_yaml-0.15.100-py37h~ --> conda-forge::ruamel_yaml-0.15.80-py38h294d835_1007
#   spyder                     pkgs/main::spyder-4.1.5-py37_0 --> conda-forge::spyder-4.1.5-py38h32f6830_0
#   spyder-kernels     pkgs/main::spyder-kernels-1.9.4-py37_0 --> conda-forge::spyder-kernels-1.9.4-py38h32f6830_0
#   webencodings       pkgs/main/win-64::webencodings-0.5.1-~ --> conda-forge/noarch::webencodings-0.5.1-py_1
#
# The following packages will be DOWNGRADED:
#
#   _ipyw_jlab_nb_ext~                           0.1.0-py37_0 --> 0.1.0-py38_0
#   anaconda-navigator                   2.1.0-py37haa95532_0 --> 2.1.0-py38haa95532_0
#
#
#
# Downloading and Extracting Packages
#
# qdarkstyle-3.0.2     | 313 KB    |            |   0%
# qdarkstyle-3.0.2     | 313 KB    | 5          |   5%
# qdarkstyle-3.0.2     | 313 KB    | #######6   |  77%
# qdarkstyle-3.0.2     | 313 KB    | ########## | 100%
#
# bcrypt-3.2.2         | 41 KB     |            |   0%
# bcrypt-3.2.2         | 41 KB     | ###8       |  39%
# bcrypt-3.2.2         | 41 KB     | ########## | 100%
#
# pyrsistent-0.18.1    | 85 KB     |            |   0%
# pyrsistent-0.18.1    | 85 KB     | #8         |  19%
# pyrsistent-0.18.1    | 85 KB     | ########## | 100%
#
# wrapt-1.14.1         | 49 KB     |            |   0%
# wrapt-1.14.1         | 49 KB     | ###2       |  33%
# wrapt-1.14.1         | 49 KB     | ########## | 100%
#
# spacy-3.4.4          | 9.4 MB    |            |   0%
# spacy-3.4.4          | 9.4 MB    |            |   0%
# spacy-3.4.4          | 9.4 MB    | 1          |   1%
# spacy-3.4.4          | 9.4 MB    | 3          |   4%
# spacy-3.4.4          | 9.4 MB    | 7          |   7%
# spacy-3.4.4          | 9.4 MB    | #3         |  14%
# spacy-3.4.4          | 9.4 MB    | ##4        |  24%
# spacy-3.4.4          | 9.4 MB    | ####2      |  42%
# spacy-3.4.4          | 9.4 MB    | ######7    |  67%
# spacy-3.4.4          | 9.4 MB    | ########9  |  90%
# spacy-3.4.4          | 9.4 MB    | ########## | 100%
#
# thinc-8.1.0          | 1.1 MB    |            |   0%
# thinc-8.1.0          | 1.1 MB    | 1          |   1%
# thinc-8.1.0          | 1.1 MB    | ########## | 100%
# thinc-8.1.0          | 1.1 MB    | ########## | 100%
#
# cython-blis-0.7.8    | 5.6 MB    |            |   0%
# cython-blis-0.7.8    | 5.6 MB    |            |   0%
# cython-blis-0.7.8    | 5.6 MB    | ###7       |  38%
# cython-blis-0.7.8    | 5.6 MB    | #######    |  71%
# cython-blis-0.7.8    | 5.6 MB    | ########## | 100%
# cython-blis-0.7.8    | 5.6 MB    | ########## | 100%
#
# tomlkit-0.11.6       | 33 KB     |            |   0%
# tomlkit-0.11.6       | 33 KB     | ####8      |  49%
# tomlkit-0.11.6       | 33 KB     | ########## | 100%
#
# text-unidecode-1.3   | 69 KB     |            |   0%
# text-unidecode-1.3   | 69 KB     | ##3        |  23%
# text-unidecode-1.3   | 69 KB     | ########## | 100%
#
# python-language-serv | 47 KB     |            |   0%
# python-language-serv | 47 KB     | ###4       |  34%
# python-language-serv | 47 KB     | ########## | 100%
#
# conda-4.12.0         | 1.0 MB    |            |   0%
# conda-4.12.0         | 1.0 MB    | 1          |   2%
# conda-4.12.0         | 1.0 MB    | ########## | 100%
# conda-4.12.0         | 1.0 MB    | ########## | 100%
#
# whichcraft-0.6.1     | 11 KB     |            |   0%
# whichcraft-0.6.1     | 11 KB     | ########## | 100%
# whichcraft-0.6.1     | 11 KB     | ########## | 100%
#
# sip-4.19.13          | 281 KB    |            |   0%
# sip-4.19.13          | 281 KB    | 5          |   6%
# sip-4.19.13          | 281 KB    | ##2        |  23%
# sip-4.19.13          | 281 KB    | ########## | 100%
# sip-4.19.13          | 281 KB    | ########## | 100%
#
# ipykernel-6.17.1     | 100 KB    |            |   0%
# ipykernel-6.17.1     | 100 KB    | #5         |  16%
# ipykernel-6.17.1     | 100 KB    | ########## | 100%
#
# anaconda-client-1.11 | 72 KB     |            |   0%
# anaconda-client-1.11 | 72 KB     | ##2        |  22%
# anaconda-client-1.11 | 72 KB     | ########## | 100%
#
# pyyaml-6.0           | 154 KB    |            |   0%
# pyyaml-6.0           | 154 KB    | #          |  10%
# pyyaml-6.0           | 154 KB    | ########## | 100%
#
# entrypoints-0.4      | 9 KB      |            |   0%
# entrypoints-0.4      | 9 KB      | ########## | 100%
#
# inflection-0.5.1     | 9 KB      |            |   0%
# inflection-0.5.1     | 9 KB      | ########## | 100%
# inflection-0.5.1     | 9 KB      | ########## | 100%
#
# mccabe-0.6.1         | 8 KB      |            |   0%
# mccabe-0.6.1         | 8 KB      | ########## | 100%
# mccabe-0.6.1         | 8 KB      | ########## | 100%
#
# numpy-1.23.2         | 6.3 MB    |            |   0%
# numpy-1.23.2         | 6.3 MB    |            |   0%
# numpy-1.23.2         | 6.3 MB    | ##9        |  29%
# numpy-1.23.2         | 6.3 MB    | ######     |  60%
# numpy-1.23.2         | 6.3 MB    | #########3 |  93%
# numpy-1.23.2         | 6.3 MB    | ########## | 100%
#
# ujson-5.4.0          | 44 KB     |            |   0%
# ujson-5.4.0          | 44 KB     | ###6       |  37%
# ujson-5.4.0          | 44 KB     | ########## | 100%
#
# pyqt-5.9.2           | 4.2 MB    |            |   0%
# pyqt-5.9.2           | 4.2 MB    |            |   0%
# pyqt-5.9.2           | 4.2 MB    | 2          |   3%
# pyqt-5.9.2           | 4.2 MB    | 8          |   8%
# pyqt-5.9.2           | 4.2 MB    | #6         |  17%
# pyqt-5.9.2           | 4.2 MB    | ###        |  30%
# pyqt-5.9.2           | 4.2 MB    | #####5     |  56%
# pyqt-5.9.2           | 4.2 MB    | #########6 |  97%
# pyqt-5.9.2           | 4.2 MB    | ########## | 100%
#
# widgetsnbextension-3 | 1.3 MB    |            |   0%
# widgetsnbextension-3 | 1.3 MB    | 1          |   1%
# widgetsnbextension-3 | 1.3 MB    | ########## | 100%
# widgetsnbextension-3 | 1.3 MB    | ########## | 100%
#
# conda-verify-3.4.2   | 25 KB     |            |   0%
# conda-verify-3.4.2   | 25 KB     | ######4    |  64%
# conda-verify-3.4.2   | 25 KB     | ########## | 100%
#
# dill-0.3.6           | 81 KB     |            |   0%
# dill-0.3.6           | 81 KB     | #9         |  20%
# dill-0.3.6           | 81 KB     | ########## | 100%
#
# flit-core-3.8.0      | 45 KB     |            |   0%
# flit-core-3.8.0      | 45 KB     | ###5       |  35%
# flit-core-3.8.0      | 45 KB     | ########## | 100%
#
# python-lsp-jsonrpc-1 | 10 KB     |            |   0%
# python-lsp-jsonrpc-1 | 10 KB     | ########## | 100%
# python-lsp-jsonrpc-1 | 10 KB     | ########## | 100%
#
# qstylizer-0.1.10     | 17 KB     |            |   0%
# qstylizer-0.1.10     | 17 KB     | #########6 |  96%
# qstylizer-0.1.10     | 17 KB     | ########## | 100%
#
# spyder-4.1.5         | 8.2 MB    |            |   0%
# spyder-4.1.5         | 8.2 MB    |            |   0%
# spyder-4.1.5         | 8.2 MB    | ##4        |  25%
# spyder-4.1.5         | 8.2 MB    | ####8      |  48%
# spyder-4.1.5         | 8.2 MB    | #######4   |  75%
# spyder-4.1.5         | 8.2 MB    | ########## | 100%
# spyder-4.1.5         | 8.2 MB    | ########## | 100%
#
# keyring-23.9.3       | 72 KB     |            |   0%
# keyring-23.9.3       | 72 KB     | ##2        |  22%
# keyring-23.9.3       | 72 KB     | ########## | 100%
#
# conda-pack-0.6.0     | 28 KB     |            |   0%
# conda-pack-0.6.0     | 28 KB     | #####6     |  56%
# conda-pack-0.6.0     | 28 KB     | ########## | 100%
#
# poyo-0.5.0           | 17 KB     |            |   0%
# poyo-0.5.0           | 17 KB     | #########5 |  95%
# poyo-0.5.0           | 17 KB     | ########## | 100%
#
# argon2-cffi-bindings | 35 KB     |            |   0%
# argon2-cffi-bindings | 35 KB     | ####6      |  46%
# argon2-cffi-bindings | 35 KB     | ########## | 100%
#
# more-itertools-9.0.0 | 46 KB     |            |   0%
# more-itertools-9.0.0 | 46 KB     | ###4       |  35%
# more-itertools-9.0.0 | 46 KB     | ########## | 100%
#
# jupyter_client-6.1.1 | 87 KB     |            |   0%
# jupyter_client-6.1.1 | 87 KB     | #8         |  18%
# jupyter_client-6.1.1 | 87 KB     | ########## | 100%
# jupyter_client-6.1.1 | 87 KB     | ########## | 100%
#
# conda-build-3.21.7   | 586 KB    |            |   0%
# conda-build-3.21.7   | 586 KB    | 2          |   3%
# conda-build-3.21.7   | 586 KB    | ########## | 100%
# conda-build-3.21.7   | 586 KB    | ########## | 100%
#
# openjpeg-2.4.0       | 238 KB    |            |   0%
# openjpeg-2.4.0       | 238 KB    | 6          |   7%
# openjpeg-2.4.0       | 238 KB    | ########## | 100%
#
# cookiecutter-1.7.2   | 89 KB     |            |   0%
# cookiecutter-1.7.2   | 89 KB     | #8         |  18%
# cookiecutter-1.7.2   | 89 KB     | ########## | 100%
# cookiecutter-1.7.2   | 89 KB     | ########## | 100%
#
# tomli-2.0.1          | 16 KB     |            |   0%
# tomli-2.0.1          | 16 KB     | ########## | 100%
#
# webencodings-0.5.1   | 12 KB     |            |   0%
# webencodings-0.5.1   | 12 KB     | ########## | 100%
# webencodings-0.5.1   | 12 KB     | ########## | 100%
#
# openpyxl-3.0.9       | 153 KB    |            |   0%
# openpyxl-3.0.9       | 153 KB    | #          |  10%
# openpyxl-3.0.9       | 153 KB    | ########## | 100%
# openpyxl-3.0.9       | 153 KB    | ########## | 100%
#
# platformdirs-2.5.2   | 16 KB     |            |   0%
# platformdirs-2.5.2   | 16 KB     | ########## | 100%
# platformdirs-2.5.2   | 16 KB     | ########## | 100%
#
# shellingham-1.5.0    | 12 KB     |            |   0%
# shellingham-1.5.0    | 12 KB     | ########## | 100%
# shellingham-1.5.0    | 12 KB     | ########## | 100%
#
# anyio-3.6.2          | 83 KB     |            |   0%
# anyio-3.6.2          | 83 KB     | #9         |  19%
# anyio-3.6.2          | 83 KB     | ########## | 100%
#
# openssl-1.1.1q       | 5.8 MB    |            |   0%
# openssl-1.1.1q       | 5.8 MB    |            |   0%
# openssl-1.1.1q       | 5.8 MB    | ###5       |  35%
# openssl-1.1.1q       | 5.8 MB    | ######7    |  68%
# openssl-1.1.1q       | 5.8 MB    | ########## | 100%
# openssl-1.1.1q       | 5.8 MB    | ########## | 100%
#
# binaryornot-0.4.4    | 375 KB    |            |   0%
# binaryornot-0.4.4    | 375 KB    | 4          |   4%
# binaryornot-0.4.4    | 375 KB    | ########1  |  81%
# binaryornot-0.4.4    | 375 KB    | ########## | 100%
#
# win_inet_pton-1.1.0  | 8 KB      |            |   0%
# win_inet_pton-1.1.0  | 8 KB      | ########## | 100%
#
# docutils-0.17.1      | 769 KB    |            |   0%
# docutils-0.17.1      | 769 KB    | 2          |   2%
# docutils-0.17.1      | 769 KB    | ########## | 100%
# docutils-0.17.1      | 769 KB    | ########## | 100%
#
# jupyter_core-5.0.0   | 110 KB    |            |   0%
# jupyter_core-5.0.0   | 110 KB    | #4         |  15%
# jupyter_core-5.0.0   | 110 KB    | ########## | 100%
#
# executing-1.2.0      | 24 KB     |            |   0%
# executing-1.2.0      | 24 KB     | ######5    |  66%
# executing-1.2.0      | 24 KB     | ########## | 100%
#
# certifi-2022.9.24    | 155 KB    |            |   0%
# certifi-2022.9.24    | 155 KB    | #          |  10%
# certifi-2022.9.24    | 155 KB    | ########## | 100%
#
# ruamel_yaml-0.15.80  | 279 KB    |            |   0%
# ruamel_yaml-0.15.80  | 279 KB    | 5          |   6%
# ruamel_yaml-0.15.80  | 279 KB    | ########## | 100%
# ruamel_yaml-0.15.80  | 279 KB    | ########## | 100%
#
# matplotlib-base-3.5. | 7.3 MB    |            |   0%
# matplotlib-base-3.5. | 7.3 MB    |            |   0%
# matplotlib-base-3.5. | 7.3 MB    | ##9        |  30%
# matplotlib-base-3.5. | 7.3 MB    | ######     |  60%
# matplotlib-base-3.5. | 7.3 MB    | ########4  |  84%
# matplotlib-base-3.5. | 7.3 MB    | ########## | 100%
#
# debugpy-1.6.3        | 3.2 MB    |            |   0%
# debugpy-1.6.3        | 3.2 MB    |            |   0%
# debugpy-1.6.3        | 3.2 MB    | ######6    |  66%
# debugpy-1.6.3        | 3.2 MB    | ########## | 100%
# debugpy-1.6.3        | 3.2 MB    | ########## | 100%
#
# psutil-5.9.1         | 363 KB    |            |   0%
# psutil-5.9.1         | 363 KB    | 4          |   4%
# psutil-5.9.1         | 363 KB    | ########## | 100%
# psutil-5.9.1         | 363 KB    | ########## | 100%
#
# zeromq-4.3.4         | 8.9 MB    |            |   0%
# zeromq-4.3.4         | 8.9 MB    |            |   0%
# zeromq-4.3.4         | 8.9 MB    | ##1        |  22%
# zeromq-4.3.4         | 8.9 MB    | ####6      |  46%
# zeromq-4.3.4         | 8.9 MB    | #######1   |  72%
# zeromq-4.3.4         | 8.9 MB    | #########5 |  95%
# zeromq-4.3.4         | 8.9 MB    | ########## | 100%
#
# murmurhash-1.0.8     | 25 KB     |            |   0%
# murmurhash-1.0.8     | 25 KB     | ######5    |  65%
# murmurhash-1.0.8     | 25 KB     | ########## | 100%
#
# pip-22.3.1           | 1.5 MB    |            |   0%
# pip-22.3.1           | 1.5 MB    | 1          |   1%
# pip-22.3.1           | 1.5 MB    | ########## | 100%
# pip-22.3.1           | 1.5 MB    | ########## | 100%
#
# wasabi-0.10.1        | 25 KB     |            |   0%
# wasabi-0.10.1        | 25 KB     | ######3    |  64%
# wasabi-0.10.1        | 25 KB     | ########## | 100%
#
# pillow-8.2.0         | 775 KB    |            |   0%
# pillow-8.2.0         | 775 KB    | 2          |   2%
# pillow-8.2.0         | 775 KB    | ########## | 100%
# pillow-8.2.0         | 775 KB    | ########## | 100%
#
# anaconda-navigator-2 | 5.9 MB    |            |   0%
# anaconda-navigator-2 | 5.9 MB    |            |   0%
# anaconda-navigator-2 | 5.9 MB    | 1          |   1%
# anaconda-navigator-2 | 5.9 MB    | 3          |   3%
# anaconda-navigator-2 | 5.9 MB    | 6          |   7%
# anaconda-navigator-2 | 5.9 MB    | #3         |  14%
# anaconda-navigator-2 | 5.9 MB    | ##4        |  25%
# anaconda-navigator-2 | 5.9 MB    | ####2      |  42%
# anaconda-navigator-2 | 5.9 MB    | ######9    |  70%
# anaconda-navigator-2 | 5.9 MB    | ########## | 100%
# anaconda-navigator-2 | 5.9 MB    | ########## | 100%
#
# spyder-kernels-1.9.4 | 90 KB     |            |   0%
# spyder-kernels-1.9.4 | 90 KB     | #7         |  18%
# spyder-kernels-1.9.4 | 90 KB     | ########## | 100%
#
# pywin32-ctypes-0.2.0 | 39 KB     |            |   0%
# pywin32-ctypes-0.2.0 | 39 KB     | ####       |  41%
# pywin32-ctypes-0.2.0 | 39 KB     | ########## | 100%
#
# pywin32-303          | 6.9 MB    |            |   0%
# pywin32-303          | 6.9 MB    |            |   0%
# pywin32-303          | 6.9 MB    | #4         |  15%
# pywin32-303          | 6.9 MB    | ##8        |  29%
# pywin32-303          | 6.9 MB    | ####7      |  47%
# pywin32-303          | 6.9 MB    | #######    |  70%
# pywin32-303          | 6.9 MB    | #########7 |  98%
# pywin32-303          | 6.9 MB    | ########## | 100%
#
# python-3.8.12        | 19.2 MB   |            |   0%
# python-3.8.12        | 19.2 MB   |            |   0%
# python-3.8.12        | 19.2 MB   | 9          |   9%
# python-3.8.12        | 19.2 MB   | #9         |  20%
# python-3.8.12        | 19.2 MB   | ###        |  31%
# python-3.8.12        | 19.2 MB   | ####3      |  43%
# python-3.8.12        | 19.2 MB   | #####5     |  55%
# python-3.8.12        | 19.2 MB   | ######5    |  66%
# python-3.8.12        | 19.2 MB   | #######6   |  77%
# python-3.8.12        | 19.2 MB   | #########  |  91%
# python-3.8.12        | 19.2 MB   | ########## | 100%
#
# h5py-3.7.0           | 1.0 MB    |            |   0%
# h5py-3.7.0           | 1.0 MB    | 1          |   2%
# h5py-3.7.0           | 1.0 MB    | 7          |   8%
# h5py-3.7.0           | 1.0 MB    | ##3        |  23%
# h5py-3.7.0           | 1.0 MB    | ####6      |  47%
# h5py-3.7.0           | 1.0 MB    | #########1 |  92%
# h5py-3.7.0           | 1.0 MB    | ########## | 100%
#
# spacy-loggers-1.0.3  | 13 KB     |            |   0%
# spacy-loggers-1.0.3  | 13 KB     | ########## | 100%
# spacy-loggers-1.0.3  | 13 KB     | ########## | 100%
#
# setuptools-65.5.1    | 731 KB    |            |   0%
# setuptools-65.5.1    | 731 KB    | 2          |   2%
# setuptools-65.5.1    | 731 KB    | ########## | 100%
# setuptools-65.5.1    | 731 KB    | ########## | 100%
#
# srsly-2.4.4          | 518 KB    |            |   0%
# srsly-2.4.4          | 518 KB    | 3          |   3%
# srsly-2.4.4          | 518 KB    | ########## | 100%
# srsly-2.4.4          | 518 KB    | ########## | 100%
#
# pandocfilters-1.5.0  | 11 KB     |            |   0%
# pandocfilters-1.5.0  | 11 KB     | ########## | 100%
#
# astroid-2.11.6       | 353 KB    |            |   0%
# astroid-2.11.6       | 353 KB    | 4          |   5%
# astroid-2.11.6       | 353 KB    | ########## | 100%
# astroid-2.11.6       | 353 KB    | ########## | 100%
#
# jinja2-time-0.2.0    | 14 KB     |            |   0%
# jinja2-time-0.2.0    | 14 KB     | ########## | 100%
# jinja2-time-0.2.0    | 14 KB     | ########## | 100%
#
# nbconvert-6.4.4      | 588 KB    |            |   0%
# nbconvert-6.4.4      | 588 KB    | 2          |   3%
# nbconvert-6.4.4      | 588 KB    | ########## | 100%
# nbconvert-6.4.4      | 588 KB    | ########## | 100%
#
# typer-0.4.2          | 45 KB     |            |   0%
# typer-0.4.2          | 45 KB     | ###5       |  35%
# typer-0.4.2          | 45 KB     | ########## | 100%
# typer-0.4.2          | 45 KB     | ########## | 100%
#
# arrow-0.10.0         | 30 KB     |            |   0%
# arrow-0.10.0         | 30 KB     | #####3     |  54%
# arrow-0.10.0         | 30 KB     | ########## | 100%
#
# pynacl-1.5.0         | 1.5 MB    |            |   0%
# pynacl-1.5.0         | 1.5 MB    | 1          |   1%
# pynacl-1.5.0         | 1.5 MB    | ####6      |  46%
# pynacl-1.5.0         | 1.5 MB    | #########1 |  91%
# pynacl-1.5.0         | 1.5 MB    | ########## | 100%
#
# jupyter_server-1.15. | 233 KB    |            |   0%
# jupyter_server-1.15. | 233 KB    | 6          |   7%
# jupyter_server-1.15. | 233 KB    | ########## | 100%
# jupyter_server-1.15. | 233 KB    | ########## | 100%
#
# pandoc-2.19.2        | 18.8 MB   |            |   0%
# pandoc-2.19.2        | 18.8 MB   |            |   0%
# pandoc-2.19.2        | 18.8 MB   | 7          |   8%
# pandoc-2.19.2        | 18.8 MB   | #5         |  15%
# pandoc-2.19.2        | 18.8 MB   | ##3        |  24%
# pandoc-2.19.2        | 18.8 MB   | ###3       |  33%
# pandoc-2.19.2        | 18.8 MB   | ####2      |  43%
# pandoc-2.19.2        | 18.8 MB   | #####3     |  53%
# pandoc-2.19.2        | 18.8 MB   | ######3    |  63%
# pandoc-2.19.2        | 18.8 MB   | #######2   |  73%
# pandoc-2.19.2        | 18.8 MB   | ########3  |  84%
# pandoc-2.19.2        | 18.8 MB   | #########4 |  95%
# pandoc-2.19.2        | 18.8 MB   | ########## | 100%
#
# et_xmlfile-1.0.1     | 11 KB     |            |   0%
# et_xmlfile-1.0.1     | 11 KB     | ########## | 100%
# et_xmlfile-1.0.1     | 11 KB     | ########## | 100%
#
# jaraco.classes-3.2.3 | 10 KB     |            |   0%
# jaraco.classes-3.2.3 | 10 KB     | ########## | 100%
# jaraco.classes-3.2.3 | 10 KB     | ########## | 100%
#
# ca-certificates-2022 | 189 KB    |            |   0%
# ca-certificates-2022 | 189 KB    | 8          |   8%
# ca-certificates-2022 | 189 KB    | ########## | 100%
#
# cycler-0.11.0        | 10 KB     |            |   0%
# cycler-0.11.0        | 10 KB     | ########## | 100%
#
# importlib-metadata-4 | 33 KB     |            |   0%
# importlib-metadata-4 | 33 KB     | ####8      |  49%
# importlib-metadata-4 | 33 KB     | ########## | 100%
#
# backports.weakref-1. | 7 KB      |            |   0%
# backports.weakref-1. | 7 KB      | ########## | 100%
# backports.weakref-1. | 7 KB      | ########## | 100%
#
# unidecode-1.2.0      | 155 KB    |            |   0%
# unidecode-1.2.0      | 155 KB    | #          |  10%
# unidecode-1.2.0      | 155 KB    | ########## | 100%
# unidecode-1.2.0      | 155 KB    | ########## | 100%
#
# backports.functools_ | 9 KB      |            |   0%
# backports.functools_ | 9 KB      | ########## | 100%
# backports.functools_ | 9 KB      | ########## | 100%
#
# pkginfo-1.8.3        | 23 KB     |            |   0%
# pkginfo-1.8.3        | 23 KB     | ######8    |  69%
# pkginfo-1.8.3        | 23 KB     | ########## | 100%
#
# python_abi-3.8       | 4 KB      |            |   0%
# python_abi-3.8       | 4 KB      | ########## | 100%
# python_abi-3.8       | 4 KB      | ########## | 100%
#
# argon2-cffi-21.3.0   | 15 KB     |            |   0%
# argon2-cffi-21.3.0   | 15 KB     | ########## | 100%
# argon2-cffi-21.3.0   | 15 KB     | ########## | 100%
#
# mistune-0.8.4        | 55 KB     |            |   0%
# mistune-0.8.4        | 55 KB     | ##9        |  29%
# mistune-0.8.4        | 55 KB     | ########## | 100%
#
# watchdog-2.1.9       | 116 KB    |            |   0%
# watchdog-2.1.9       | 116 KB    | #3         |  14%
# watchdog-2.1.9       | 116 KB    | ########## | 100%
#
# sniffio-1.3.0        | 14 KB     |            |   0%
# sniffio-1.3.0        | 14 KB     | ########## | 100%
# sniffio-1.3.0        | 14 KB     | ########## | 100%
#
# pluggy-1.0.0         | 16 KB     |            |   0%
# pluggy-1.0.0         | 16 KB     | ########## | 100%
# pluggy-1.0.0         | 16 KB     | ########## | 100%
#
# jedi-0.17.1          | 943 KB    |            |   0%
# jedi-0.17.1          | 943 KB    | 1          |   2%
# jedi-0.17.1          | 943 KB    | ########## | 100%
# jedi-0.17.1          | 943 KB    | ########## | 100%
#
# pywinpty-0.5.7       | 51 KB     |            |   0%
# pywinpty-0.5.7       | 51 KB     | ###1       |  31%
# pywinpty-0.5.7       | 51 KB     | ########## | 100%
#
# _ipyw_jlab_nb_ext_co | 170 KB    |            |   0%
# _ipyw_jlab_nb_ext_co | 170 KB    | 9          |   9%
# _ipyw_jlab_nb_ext_co | 170 KB    | ###7       |  38%
# _ipyw_jlab_nb_ext_co | 170 KB    | ########## | 100%
#
# pylint-2.14.4        | 316 KB    |            |   0%
# pylint-2.14.4        | 316 KB    | 5          |   5%
# pylint-2.14.4        | 316 KB    | ########## | 100%
# pylint-2.14.4        | 316 KB    | ########## | 100%
#
# smart_open-5.2.1     | 43 KB     |            |   0%
# smart_open-5.2.1     | 43 KB     | ###7       |  37%
# smart_open-5.2.1     | 43 KB     | ########## | 100%
#
# mypy_extensions-0.4. | 11 KB     |            |   0%
# mypy_extensions-0.4. | 11 KB     | ########## | 100%
# mypy_extensions-0.4. | 11 KB     | ########## | 100%
#
# kiwisolver-1.4.4     | 61 KB     |            |   0%
# kiwisolver-1.4.4     | 61 KB     | ##6        |  26%
# kiwisolver-1.4.4     | 61 KB     | ########## | 100%
#
# markupsafe-1.1.1     | 30 KB     |            |   0%
# markupsafe-1.1.1     | 30 KB     | #####3     |  53%
# markupsafe-1.1.1     | 30 KB     | ########## | 100%
#
# websocket-client-1.4 | 43 KB     |            |   0%
# websocket-client-1.4 | 43 KB     | ###7       |  37%
# websocket-client-1.4 | 43 KB     | ########## | 100%
#
# typed-ast-1.5.4      | 136 KB    |            |   0%
# typed-ast-1.5.4      | 136 KB    | #1         |  12%
# typed-ast-1.5.4      | 136 KB    | ########## | 100%
#
# menuinst-1.4.19      | 97 KB     |            |   0%
# menuinst-1.4.19      | 97 KB     | #6         |  16%
# menuinst-1.4.19      | 97 KB     | ########## | 100%
#
# pure_eval-0.2.2      | 14 KB     |            |   0%
# pure_eval-0.2.2      | 14 KB     | ########## | 100%
# pure_eval-0.2.2      | 14 KB     | ########## | 100%
#
# catalogue-2.0.8      | 33 KB     |            |   0%
# catalogue-2.0.8      | 33 KB     | ####8      |  49%
# catalogue-2.0.8      | 33 KB     | ########## | 100%
#
# liblapack-3.9.0      | 5.6 MB    |            |   0%
# liblapack-3.9.0      | 5.6 MB    |            |   0%
# liblapack-3.9.0      | 5.6 MB    | ###6       |  37%
# liblapack-3.9.0      | 5.6 MB    | #######5   |  76%
# liblapack-3.9.0      | 5.6 MB    | ########## | 100%
#
# preshed-3.0.7        | 84 KB     |            |   0%
# preshed-3.0.7        | 84 KB     | #8         |  19%
# preshed-3.0.7        | 84 KB     | ########## | 100%
#
# tinycss-0.4          | 39 KB     |            |   0%
# tinycss-0.4          | 39 KB     | ####1      |  41%
# tinycss-0.4          | 39 KB     | ########## | 100%
#
# libsodium-1.0.18     | 697 KB    |            |   0%
# libsodium-1.0.18     | 697 KB    | ########## | 100%
# libsodium-1.0.18     | 697 KB    | ########## | 100%
#
# scipy-1.8.1          | 27.2 MB   |            |   0%
# scipy-1.8.1          | 27.2 MB   |            |   0%
# scipy-1.8.1          | 27.2 MB   | 2          |   2%
# scipy-1.8.1          | 27.2 MB   | 4          |   5%
# scipy-1.8.1          | 27.2 MB   | 9          |   9%
# scipy-1.8.1          | 27.2 MB   | #4         |  14%
# scipy-1.8.1          | 27.2 MB   | #9         |  19%
# scipy-1.8.1          | 27.2 MB   | ##5        |  25%
# scipy-1.8.1          | 27.2 MB   | ###1       |  31%
# scipy-1.8.1          | 27.2 MB   | ###7       |  38%
# scipy-1.8.1          | 27.2 MB   | ####3      |  43%
# scipy-1.8.1          | 27.2 MB   | ####9      |  49%
# scipy-1.8.1          | 27.2 MB   | #####6     |  56%
# scipy-1.8.1          | 27.2 MB   | ######2    |  63%
# scipy-1.8.1          | 27.2 MB   | ######9    |  70%
# scipy-1.8.1          | 27.2 MB   | #######7   |  77%
# scipy-1.8.1          | 27.2 MB   | ########5  |  85%
# scipy-1.8.1          | 27.2 MB   | #########3 |  93%
# scipy-1.8.1          | 27.2 MB   | ########## | 100%
#
# pyzmq-23.2.1         | 442 KB    |            |   0%
# pyzmq-23.2.1         | 442 KB    | 3          |   4%
# pyzmq-23.2.1         | 442 KB    | #######2   |  72%
# pyzmq-23.2.1         | 442 KB    | ########## | 100%
#
# pycosat-0.6.3        | 98 KB     |            |   0%
# pycosat-0.6.3        | 98 KB     | #6         |  16%
# pycosat-0.6.3        | 98 KB     | ########## | 100%
#
# chardet-5.0.0        | 250 KB    |            |   0%
# chardet-5.0.0        | 250 KB    | 6          |   6%
# chardet-5.0.0        | 250 KB    | ####4      |  45%
# chardet-5.0.0        | 250 KB    | ########## | 100%
# chardet-5.0.0        | 250 KB    | ########## | 100%
#
# typing-extensions-3. | 12 KB     |            |   0%
# typing-extensions-3. | 12 KB     | ########## | 100%
# typing-extensions-3. | 12 KB     | ########## | 100%
#
# ipython-8.6.0        | 559 KB    |            |   0%
# ipython-8.6.0        | 559 KB    | 2          |   3%
# ipython-8.6.0        | 559 KB    | ########## | 100%
# ipython-8.6.0        | 559 KB    | ########## | 100%
#
# notebook-6.4.12      | 6.3 MB    |            |   0%
# notebook-6.4.12      | 6.3 MB    |            |   0%
# notebook-6.4.12      | 6.3 MB    | ###        |  31%
# notebook-6.4.12      | 6.3 MB    | ######8    |  68%
# notebook-6.4.12      | 6.3 MB    | ########## | 100%
# notebook-6.4.12      | 6.3 MB    | ########## | 100%
#
# asttokens-2.1.0      | 26 KB     |            |   0%
# asttokens-2.1.0      | 26 KB     | ######     |  60%
# asttokens-2.1.0      | 26 KB     | ########## | 100%
#
# cffi-1.15.1          | 223 KB    |            |   0%
# cffi-1.15.1          | 223 KB    | 7          |   7%
# cffi-1.15.1          | 223 KB    | ########## | 100%
#
# langcodes-3.3.0      | 156 KB    |            |   0%
# langcodes-3.3.0      | 156 KB    | #          |  10%
# langcodes-3.3.0      | 156 KB    | ########## | 100%
#
# pyjwt-2.6.0          | 21 KB     |            |   0%
# pyjwt-2.6.0          | 21 KB     | #######6   |  76%
# pyjwt-2.6.0          | 21 KB     | ########## | 100%
#
# typing-3.10.0.0      | 7 KB      |            |   0%
# typing-3.10.0.0      | 7 KB      | ########## | 100%
# typing-3.10.0.0      | 7 KB      | ########## | 100%
#
# backports-1.0        | 185 KB    |            |   0%
# backports-1.0        | 185 KB    | 8          |   9%
# backports-1.0        | 185 KB    | ########## | 100%
# backports-1.0        | 185 KB    | ########## | 100%
#
# lcms2-2.12           | 882 KB    |            |   0%
# lcms2-2.12           | 882 KB    | ########## | 100%
# lcms2-2.12           | 882 KB    | ########## | 100%
#
# rtree-1.0.1          | 50 KB     |            |   0%
# rtree-1.0.1          | 50 KB     | ###2       |  32%
# rtree-1.0.1          | 50 KB     | ########## | 100%
#
# matplotlib-3.5.3     | 7 KB      |            |   0%
# matplotlib-3.5.3     | 7 KB      | ########## | 100%
# matplotlib-3.5.3     | 7 KB      | ########## | 100%
#
# python-slugify-5.0.2 | 13 KB     |            |   0%
# python-slugify-5.0.2 | 13 KB     | ########## | 100%
# python-slugify-5.0.2 | 13 KB     | ########## | 100%
#
# terminado-0.9.5      | 26 KB     |            |   0%
# terminado-0.9.5      | 26 KB     | ######     |  61%
# terminado-0.9.5      | 26 KB     | ########## | 100%
#
# conda-package-handli | 751 KB    |            |   0%
# conda-package-handli | 751 KB    | 2          |   2%
# conda-package-handli | 751 KB    | ########## | 100%
# conda-package-handli | 751 KB    | ########## | 100%
#
# clyent-1.2.2         | 9 KB      |            |   0%
# clyent-1.2.2         | 9 KB      | ########## | 100%
# clyent-1.2.2         | 9 KB      | ########## | 100%
#
# sphinx-4.2.0         | 1.5 MB    |            |   0%
# sphinx-4.2.0         | 1.5 MB    | 1          |   1%
# sphinx-4.2.0         | 1.5 MB    | ###3       |  34%
# sphinx-4.2.0         | 1.5 MB    | ######6    |  67%
# sphinx-4.2.0         | 1.5 MB    | ########## | 100%
# sphinx-4.2.0         | 1.5 MB    | ########## | 100%
#
# spacy-legacy-3.0.10  | 20 KB     |            |   0%
# spacy-legacy-3.0.10  | 20 KB     | #######9   |  79%
# spacy-legacy-3.0.10  | 20 KB     | ########## | 100%
#
# regex-2022.8.17      | 334 KB    |            |   0%
# regex-2022.8.17      | 334 KB    | 4          |   5%
# regex-2022.8.17      | 334 KB    | ########## | 100%
#
# pysocks-1.7.1        | 19 KB     |            |   0%
# pysocks-1.7.1        | 19 KB     | ########## | 100%
#
# lazy-object-proxy-1. | 33 KB     |            |   0%
# lazy-object-proxy-1. | 33 KB     | ####8      |  49%
# lazy-object-proxy-1. | 33 KB     | ########## | 100%
#
# cymem-2.0.6          | 34 KB     |            |   0%
# cymem-2.0.6          | 34 KB     | ####6      |  47%
# cymem-2.0.6          | 34 KB     | ########## | 100%
#
# pathy-0.8.1          | 39 KB     |            |   0%
# pathy-0.8.1          | 39 KB     | ####       |  41%
# pathy-0.8.1          | 39 KB     | ########## | 100%
#
# navigator-updater-0. | 3.0 MB    |            |   0%
# navigator-updater-0. | 3.0 MB    |            |   1%
# navigator-updater-0. | 3.0 MB    | 2          |   2%
# navigator-updater-0. | 3.0 MB    | 7          |   8%
# navigator-updater-0. | 3.0 MB    | #4         |  14%
# navigator-updater-0. | 3.0 MB    | ##8        |  28%
# navigator-updater-0. | 3.0 MB    | ####9      |  50%
# navigator-updater-0. | 3.0 MB    | #########  |  90%
# navigator-updater-0. | 3.0 MB    | ########## | 100%
#
# stack_data-0.6.1     | 24 KB     |            |   0%
# stack_data-0.6.1     | 24 KB     | ######6    |  67%
# stack_data-0.6.1     | 24 KB     | ########## | 100%
#
# brotlipy-0.7.0       | 329 KB    |            |   0%
# brotlipy-0.7.0       | 329 KB    | 4          |   5%
# brotlipy-0.7.0       | 329 KB    | ########## | 100%
#
# libblas-3.9.0        | 5.6 MB    |            |   0%
# libblas-3.9.0        | 5.6 MB    |            |   0%
# libblas-3.9.0        | 5.6 MB    | 2          |   2%
# libblas-3.9.0        | 5.6 MB    | 5          |   6%
# libblas-3.9.0        | 5.6 MB    | #1         |  11%
# libblas-3.9.0        | 5.6 MB    | ##         |  20%
# libblas-3.9.0        | 5.6 MB    | ###4       |  34%
# libblas-3.9.0        | 5.6 MB    | ######     |  60%
# libblas-3.9.0        | 5.6 MB    | #########4 |  94%
# libblas-3.9.0        | 5.6 MB    | ########## | 100%
#
# future-0.18.2        | 356 KB    |            |   0%
# future-0.18.2        | 356 KB    | 4          |   4%
# future-0.18.2        | 356 KB    | ########## | 100%
# future-0.18.2        | 356 KB    | ########## | 100%
#
# cryptography-37.0.4  | 1.1 MB    |            |   0%
# cryptography-37.0.4  | 1.1 MB    | 1          |   1%
# cryptography-37.0.4  | 1.1 MB    | ########## | 100%
# cryptography-37.0.4  | 1.1 MB    | ########## | 100%
#
# pydantic-1.9.2       | 1.7 MB    |            |   0%
# pydantic-1.9.2       | 1.7 MB    |            |   1%
# pydantic-1.9.2       | 1.7 MB    | #1         |  11%
# pydantic-1.9.2       | 1.7 MB    | ##3        |  23%
# pydantic-1.9.2       | 1.7 MB    | ####9      |  49%
# pydantic-1.9.2       | 1.7 MB    | ########6  |  86%
# pydantic-1.9.2       | 1.7 MB    | ########## | 100%
#
# tornado-6.2          | 655 KB    |            |   0%
# tornado-6.2          | 655 KB    | 2          |   2%
# tornado-6.2          | 655 KB    | ########## | 100%
# tornado-6.2          | 655 KB    | ########## | 100%
#
# libcblas-3.9.0       | 5.6 MB    |            |   0%
# libcblas-3.9.0       | 5.6 MB    |            |   0%
# libcblas-3.9.0       | 5.6 MB    | 1          |   1%
# libcblas-3.9.0       | 5.6 MB    | 3          |   3%
# libcblas-3.9.0       | 5.6 MB    | 6          |   7%
# libcblas-3.9.0       | 5.6 MB    | #2         |  12%
# libcblas-3.9.0       | 5.6 MB    | ##3        |  23%
# libcblas-3.9.0       | 5.6 MB    | ###9       |  40%
# libcblas-3.9.0       | 5.6 MB    | ######6    |  66%
# libcblas-3.9.0       | 5.6 MB    | #########8 |  99%
# libcblas-3.9.0       | 5.6 MB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: ok
#
# done

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import spacy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-49-048ffe681e3c> in <module>
#       2 from nltk.tokenize import word_tokenize
#       3 from nltk.stem import WordNetLemmatizer
# ----> 4 import spacy
#
# ModuleNotFoundError: No module named 'spacy'

# %%
nltk.download('wordnet')

# %%
nltk.download('omw-1.4')

# %%
nltk.download('punkt')

# %%
def preprocess_text(data):
    lemmatizer = WordNetLemmatizer()
    data = data.lower()
    tokens = word_tokenize(data)
    tokens = [i for i in tokens if i.isalpha()]
    lemmatized_tokens = [lemmatizer.lemmatize(token) for token in tokens]
    return tokens

# %%
preprocess_text(data["Review"][-1])
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\nltk\corpus\util.py in __load(self)
#      83                 try:
# ---> 84                     root = nltk.data.find(f"{self.subdir}/{zip_name}")
#      85                 except LookupError:
#
# ~\Anaconda3\lib\site-packages\nltk\data.py in find(resource_name, paths)
#     582     resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 583     raise LookupError(resource_not_found)
#     584
#
# LookupError:
# **********************************************************************
#   Resource wordnet not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('wordnet')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/wordnet.zip/wordnet/
#
#   Searched in:
#     - 'C:\\Users\\julie/nltk_data'
#     - 'C:\\Users\\julie\\Anaconda3\\nltk_data'
#     - 'C:\\Users\\julie\\Anaconda3\\share\\nltk_data'
#     - 'C:\\Users\\julie\\Anaconda3\\lib\\nltk_data'
#     - 'C:\\Users\\julie\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
#
#
# During handling of the above exception, another exception occurred:
#
# LookupError                               Traceback (most recent call last)
# <ipython-input-44-dcefdce921aa> in <module>
# ----> 1 preprocess_text(data["Review"][-1])
#
# <ipython-input-43-21cf3eb8d277> in preprocess_text(data)
#       4     tokens = word_tokenize(data)
#       5     tokens = [i for i in tokens if i.isalpha()]
# ----> 6     lemmatized_tokens = [lemmatizer.lemmatize(token) for token in tokens]
#       7     return tokens
#
# <ipython-input-43-21cf3eb8d277> in <listcomp>(.0)
#       4     tokens = word_tokenize(data)
#       5     tokens = [i for i in tokens if i.isalpha()]
# ----> 6     lemmatized_tokens = [lemmatizer.lemmatize(token) for token in tokens]
#       7     return tokens
#
# ~\Anaconda3\lib\site-packages\nltk\stem\wordnet.py in lemmatize(self, word, pos)
#      43         :return: The lemma of `word`, for the given `pos`.
#      44         """
# ---> 45         lemmas = wn._morphy(word, pos)
#      46         return min(lemmas, key=len) if lemmas else word
#      47
#
# ~\Anaconda3\lib\site-packages\nltk\corpus\util.py in __getattr__(self, attr)
#     119             raise AttributeError("LazyCorpusLoader object has no attribute '__bases__'")
#     120
# --> 121         self.__load()
#     122         # This looks circular, but its not, since __load() changes our
#     123         # __class__ to something new:
#
# ~\Anaconda3\lib\site-packages\nltk\corpus\util.py in __load(self)
#      84                     root = nltk.data.find(f"{self.subdir}/{zip_name}")
#      85                 except LookupError:
# ---> 86                     raise e
#      87
#      88         # Load the corpus.
#
# ~\Anaconda3\lib\site-packages\nltk\corpus\util.py in __load(self)
#      79         else:
#      80             try:
# ---> 81                 root = nltk.data.find(f"{self.subdir}/{self.__name}")
#      82             except LookupError as e:
#      83                 try:
#
# ~\Anaconda3\lib\site-packages\nltk\data.py in find(resource_name, paths)
#     581     sep = "*" * 70
#     582     resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 583     raise LookupError(resource_not_found)
#     584
#     585
#
# LookupError:
# **********************************************************************
#   Resource wordnet not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('wordnet')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/wordnet
#
#   Searched in:
#     - 'C:\\Users\\julie/nltk_data'
#     - 'C:\\Users\\julie\\Anaconda3\\nltk_data'
#     - 'C:\\Users\\julie\\Anaconda3\\share\\nltk_data'
#     - 'C:\\Users\\julie\\Anaconda3\\lib\\nltk_data'
#     - 'C:\\Users\\julie\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
